# %%
import os
path='C:/Users/msi/vote/'
os.listdir(path)
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '11시 40분.hwp',
#  'all_NA.ipynb',
#  'catboost_info',
#  'data.csv',
#  'engnatNA.ipynb',
#  'logs.log',
#  'Machiavellianism_data_visualized_for_EDA.ipynb',
#  'Maciavellianism_data_visualized_for_EDA.ipynb',
#  'marriedNA.ipynb',
#  'mlruns',
#  'personal_data_visualized_for_EDA.ipynb',
#  'PoC1_3.ipynb',
#  'PoC1_4&2_1.ipynb',
#  'PoC2_3.ipynb',
#  'race_religion.csv',
#  'README.md',
#  'sample_submission.csv',
#  'self_describe_data_visualized_for_EDA.ipynb',
#  'submission_proba.csv',
#  'test_preprocessed.csv',
#  'test_x.csv',
#  'train.csv',
#  'train_preprocessed.csv',
#  'vocab_data_visualized_for_EDA.ipynb',
#  'vote_machinelearning.ipynb',
#  'vote_machinelearning_NA.ipynb',
#  'vote_machinelearning_NA2.ipynb',
#  'word.ipynb',
#  '데이터 정보.md',
#  '회의1016.pdf']

# %%
import pandas as pd
train = pd.read_csv(path + 'train_preprocessed.csv')
test = pd.read_csv(path + 'test_preprocessed.csv')
submission = pd.read_csv(path + 'sample_submission.csv')

# %%
total_negative_cols = ["QeA", "QfA", "QkA", "QqA", "QrA", "QaA", "QdA", "QgA", "QiA", "QnA"]
train[total_negative_cols] = 6-train[total_negative_cols]
train['mach_score'] = train.apply(lambda x:x.iloc[0:40:2].mean(),axis=1)

# %%
train[['tp02','tp04','tp06','tp08','tp10']]= 6-train[['tp02','tp04','tp06','tp08','tp10']]

train['Extraversion']=(train.tp01+train.tp06)/2
train['Agreeableness']=(train.tp02+train.tp07)/2
train['Conscientiousness']=(train.tp03+train.tp08)/2
train['Emotional Stability']=(train.tp04+train.tp09)/2
train['Openness to Experiences']=(train.tp05+train.tp10)/2

# %%
total_negative_cols = ["QeA", "QfA", "QkA", "QqA", "QrA", "QaA", "QdA", "QgA", "QiA", "QnA"]
test[total_negative_cols] = 6-test[total_negative_cols]
test['mach_score'] = test.apply(lambda x:x.iloc[0:40:2].mean(),axis=1)

# %%
test[['tp02','tp04','tp06','tp08','tp10']]= 6-test[['tp02','tp04','tp06','tp08','tp10']]

test['Extraversion']=(test.tp01+test.tp06)/2
test['Agreeableness']=(test.tp02+test.tp07)/2
test['Conscientiousness']=(test.tp03+test.tp08)/2
test['Emotional Stability']=(test.tp04+test.tp09)/2
test['Openness to Experiences']=(test.tp05+test.tp10)/2

# %%
test
# Out:
#        QaA  QaE  QbA   QbE  QcA   QcE  QdA   QdE  QeA   QeE  ...  wr_10  \
# 0      3.0  736  2.0  2941  3.0  4621  5.0  4857  4.0  2550  ...      1
# 1      3.0  514  2.0  1952  3.0  1552  3.0   821  2.0  1150  ...      0
# 2      3.0  500  2.0  2507  4.0   480  4.0   614  4.0  1326  ...      1
# 3      5.0  669  1.0  1050  5.0  1435  4.0  2252  1.0  2533  ...      1
# 4      4.0  499  1.0  1243  5.0   845  4.0  1666  4.0   925  ...      1
# ...    ...  ...  ...   ...  ...   ...  ...   ...  ...   ...  ...    ...
# 11378  1.0  427  5.0  1066  5.0   588  5.0   560  4.0  1110  ...      1
# 11379  5.0  314  5.0   554  5.0   230  5.0   956  4.0  1173  ...      1
# 11380  5.0  627  2.0   799  1.0   739  4.0  1123  5.0   829  ...      1
# 11381  4.0  539  1.0  2090  2.0  4642  5.0   673  4.0  1185  ...      1
# 11382  4.0  541  4.0   900  5.0   691  4.0  1951  5.0  2317  ...      0
#
#        wr_11  wr_12  wr_13  mach_score  Extraversion  Agreeableness  \
# ...

# %%
'''
train=train.drop(['QaA', 'QaE', 'QbA', 'QbE', 'QcA', 'QcE', 'QdA', 'QdE', 'QeA', 'QeE',
       'QfA', 'QfE', 'QgA', 'QgE', 'QhA', 'QhE', 'QiA', 'QiE', 'QjA', 'QjE',
       'QkA', 'QkE', 'QlA', 'QlE', 'QmA', 'QmE', 'QnA', 'QnE', 'QoA', 'QoE',
       'QpA', 'QpE', 'QqA', 'QqE', 'QrA', 'QrE', 'QsA', 'QsE', 'QtA', 'QtE',
                 'tp01', 'tp02', 'tp03', 'tp04', 'tp05',
       'tp06', 'tp07', 'tp08', 'tp09', 'tp10', 'wf_01', 'wf_02',
       'wf_03', 'wr_01', 'wr_02', 'wr_03', 'wr_04', 'wr_05', 'wr_06', 'wr_07',
       'wr_08', 'wr_09', 'wr_10', 'wr_11', 'wr_12', 'wr_13'], axis=1)
       '''
# Out:
# "\ntrain=train.drop(['QaA', 'QaE', 'QbA', 'QbE', 'QcA', 'QcE', 'QdA', 'QdE', 'QeA', 'QeE',\n       'QfA', 'QfE', 'QgA', 'QgE', 'QhA', 'QhE', 'QiA', 'QiE', 'QjA', 'QjE',\n       'QkA', 'QkE', 'QlA', 'QlE', 'QmA', 'QmE', 'QnA', 'QnE', 'QoA', 'QoE',\n       'QpA', 'QpE', 'QqA', 'QqE', 'QrA', 'QrE', 'QsA', 'QsE', 'QtA', 'QtE',\n                 'tp01', 'tp02', 'tp03', 'tp04', 'tp05',\n       'tp06', 'tp07', 'tp08', 'tp09', 'tp10', 'wf_01', 'wf_02',\n       'wf_03', 'wr_01', 'wr_02', 'wr_03', 'wr_04', 'wr_05', 'wr_06', 'wr_07',\n       'wr_08', 'wr_09', 'wr_10', 'wr_11', 'wr_12', 'wr_13'], axis=1)\n       "

# %%
train
# Out:
#        QaA   QaE  QbA   QbE  QcA   QcE  QdA   QdE  QeA   QeE  ...  wr_11  \
# 0      3.0   363  4.0  1370  5.0   997  5.0  1024  4.0  1577  ...      0
# 1      1.0   647  5.0  1313  3.0  3387  1.0  2969  5.0  4320  ...      0
# 2      2.0  1623  1.0  1480  1.0  1021  2.0  3374  1.0  1333  ...      0
# 3      3.0   504  3.0  2311  4.0   992  3.0  3245  5.0   357  ...      0
# 4      5.0   927  1.0   707  5.0   556  4.0  1062  5.0  1014  ...      1
# ...    ...   ...  ...   ...  ...   ...  ...   ...  ...   ...  ...    ...
# 45524  4.0  1050  5.0   619  4.0   328  5.0   285  5.0   602  ...      0
# 45525  4.0   581  3.0  1353  4.0  1164  5.0   798  3.0  1680  ...      0
# 45526  2.0   593  1.0   857  1.0  1047  2.0  1515  1.0  1690  ...      0
# 45527  5.0   747  3.0  1331  4.0   892  4.0  1281  5.0  1328  ...      0
# 45528  3.0   496  5.0  1827  5.0   754  3.0  1117  5.0   432  ...      0
#
#        wr_12  wr_13  voted  mach_score  Extraversion  Agreeableness  \
# ...

# %%
'''
test=test.drop(['QaA', 'QaE', 'QbA', 'QbE', 'QcA', 'QcE', 'QdA', 'QdE', 'QeA', 'QeE',
       'QfA', 'QfE', 'QgA', 'QgE', 'QhA', 'QhE', 'QiA', 'QiE', 'QjA', 'QjE',
       'QkA', 'QkE', 'QlA', 'QlE', 'QmA', 'QmE', 'QnA', 'QnE', 'QoA', 'QoE',
       'QpA', 'QpE', 'QqA', 'QqE', 'QrA', 'QrE', 'QsA', 'QsE', 'QtA', 'QtE',
                 'tp01', 'tp02', 'tp03', 'tp04', 'tp05',
       'tp06', 'tp07', 'tp08', 'tp09', 'tp10', 'wf_01', 'wf_02',
       'wf_03', 'wr_01', 'wr_02', 'wr_03', 'wr_04', 'wr_05', 'wr_06', 'wr_07',
       'wr_08', 'wr_09', 'wr_10', 'wr_11', 'wr_12', 'wr_13'], axis=1)
test'''
# Out:
# "\ntest=test.drop(['QaA', 'QaE', 'QbA', 'QbE', 'QcA', 'QcE', 'QdA', 'QdE', 'QeA', 'QeE',\n       'QfA', 'QfE', 'QgA', 'QgE', 'QhA', 'QhE', 'QiA', 'QiE', 'QjA', 'QjE',\n       'QkA', 'QkE', 'QlA', 'QlE', 'QmA', 'QmE', 'QnA', 'QnE', 'QoA', 'QoE',\n       'QpA', 'QpE', 'QqA', 'QqE', 'QrA', 'QrE', 'QsA', 'QsE', 'QtA', 'QtE',\n                 'tp01', 'tp02', 'tp03', 'tp04', 'tp05',\n       'tp06', 'tp07', 'tp08', 'tp09', 'tp10', 'wf_01', 'wf_02',\n       'wf_03', 'wr_01', 'wr_02', 'wr_03', 'wr_04', 'wr_05', 'wr_06', 'wr_07',\n       'wr_08', 'wr_09', 'wr_10', 'wr_11', 'wr_12', 'wr_13'], axis=1)\ntest"

# %%
print(train.shape)
print(test.shape)
print(submission.shape)
# Out:
# (45529, 83)
# (11383, 82)
# (11383, 2)

# %%
from pycaret.classification import *

# %%
clf = setup(data = train, target = 'voted')
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_5a171786_12d3_11eb_bee0_a0510bbec886" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5a171786_12d3_11eb_bee0_a0510bbec886level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5a171786_12d3_11eb_bee0_a0510bbec886row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_5a171786_12d3_11eb_bee0_a0510bbec886row0_col1" class="data row0 col1" >3118</td>
#             </tr>
#             <tr>
#                         <th id="T_5a171786_12d3_11eb_bee0_a0510bbec886level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5a171786_12d3_11eb_bee0_a0510bbec886row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
best_3 = compare_models(sort = 'AUC', n_select = 3)
# Out:
# <style  type="text/css" >
#     #T_02ae4b48_12d6_11eb_ab51_a0510bbec886 th {
#           text-align: left;
#     }    #T_02ae4b48_12d6_11eb_ab51_a0510bbec886row0_col0 {
#             text-align:  left;
#         }    #T_02ae4b48_12d6_11eb_ab51_a0510bbec886row0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_02ae4b48_12d6_11eb_ab51_a0510bbec886row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_02ae4b48_12d6_11eb_ab51_a0510bbec886row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_02ae4b48_12d6_11eb_ab51_a0510bbec886row0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_02ae4b48_12d6_11eb_ab51_a0510bbec886row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_02ae4b48_12d6_11eb_ab51_a0510bbec886row0_col6 {
#             : ;
#             text-align:  left;
# ...

# %%
blended = blend_models(estimator_list = best_3, fold = 5, method = 'soft')
# Out:
# <style  type="text/css" >
#     #T_b66e9986_12d6_11eb_b0c8_a0510bbec886row5_col0 {
#             background:  yellow;
#         }    #T_b66e9986_12d6_11eb_b0c8_a0510bbec886row5_col1 {
#             background:  yellow;
#         }    #T_b66e9986_12d6_11eb_b0c8_a0510bbec886row5_col2 {
#             background:  yellow;
#         }    #T_b66e9986_12d6_11eb_b0c8_a0510bbec886row5_col3 {
#             background:  yellow;
#         }    #T_b66e9986_12d6_11eb_b0c8_a0510bbec886row5_col4 {
#             background:  yellow;
#         }    #T_b66e9986_12d6_11eb_b0c8_a0510bbec886row5_col5 {
#             background:  yellow;
#         }    #T_b66e9986_12d6_11eb_b0c8_a0510bbec886row5_col6 {
#             background:  yellow;
# ...

# %%
pred_holdout = predict_model(blended)
# Out:
#                Model  Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0  Voting Classifier    0.6995  0.7679  0.6594  0.7595  0.7059  0.4019  0.4061

# %%
final_model = finalize_model(blended)

# %%
predictions = predict_model(final_model, data = test)

# %%
predictions
# Out:
#        QaA  QaE  QbA   QbE  QcA   QcE  QdA   QdE  QeA   QeE  ...  wr_12  \
# 0      3.0  736  2.0  2941  3.0  4621  5.0  4857  4.0  2550  ...      1
# 1      3.0  514  2.0  1952  3.0  1552  3.0   821  2.0  1150  ...      0
# 2      3.0  500  2.0  2507  4.0   480  4.0   614  4.0  1326  ...      1
# 3      5.0  669  1.0  1050  5.0  1435  4.0  2252  1.0  2533  ...      1
# 4      4.0  499  1.0  1243  5.0   845  4.0  1666  4.0   925  ...      1
# ...    ...  ...  ...   ...  ...   ...  ...   ...  ...   ...  ...    ...
# 11378  1.0  427  5.0  1066  5.0   588  5.0   560  4.0  1110  ...      1
# 11379  5.0  314  5.0   554  5.0   230  5.0   956  4.0  1173  ...      1
# 11380  5.0  627  2.0   799  1.0   739  4.0  1123  5.0   829  ...      1
# 11381  4.0  539  1.0  2090  2.0  4642  5.0   673  4.0  1185  ...      1
# 11382  4.0  541  4.0   900  5.0   691  4.0  1951  5.0  2317  ...      0
#
#        wr_13  mach_score  Extraversion  Agreeableness  Conscientiousness  \
# ...

# %%
submission['voted'] = predictions['Score']

# %%
submission.to_csv('submission_proba.csv', index = False)
