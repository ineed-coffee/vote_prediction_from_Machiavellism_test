# %%
import os
path='C:/Users/msi/vote/'
os.listdir(path)
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '11시 40분.hwp',
#  'all_NA.ipynb',
#  'catboost_info',
#  'data.csv',
#  'engnatNA.ipynb',
#  'logs.log',
#  'Machiavellianism_data_visualized_for_EDA.ipynb',
#  'Maciavellianism_data_visualized_for_EDA.ipynb',
#  'marriedNA.ipynb',
#  'personal_data_visualized_for_EDA.ipynb',
#  'PoC1_3.ipynb',
#  'PoC1_4&2_1.ipynb',
#  'PoC2_3.ipynb',
#  'race_religion.csv',
#  'README.md',
#  'sample_submission.csv',
#  'self_describe_data_visualized_for_EDA.ipynb',
#  'submission_proba.csv',
#  'test_preprocessed.csv',
#  'test_x.csv',
#  'train.csv',
#  'train_preprocessed.csv',
#  'vocab_data_visualized_for_EDA.ipynb',
#  'vote_machinelearning.ipynb',
#  'vote_machinelearning_NA.ipynb',
#  'vote_machinelearning_NA2.ipynb',
#  'word.ipynb',
#  '데이터 정보.md',
#  '회의1016.pdf']

# %%
import pandas as pd
train = pd.read_csv(path + 'train_preprocessed.csv')
test = pd.read_csv(path + 'test_preprocessed.csv')
submission = pd.read_csv(path + 'sample_submission.csv')

# %%
total_negative_cols = ["QeA", "QfA", "QkA", "QqA", "QrA", "QaA", "QdA", "QgA", "QiA", "QnA"]
train[total_negative_cols] = 6-train[total_negative_cols]
train['mach_score'] = train.apply(lambda x:x.iloc[0:40:2].mean(),axis=1)

# %%
train[['tp02','tp04','tp06','tp08','tp10']]= 6-train[['tp02','tp04','tp06','tp08','tp10']]

train['Extraversion']=(train.tp01+train.tp06)/2
train['Agreeableness']=(train.tp02+train.tp07)/2
train['Conscientiousness']=(train.tp03+train.tp08)/2
train['Emotional Stability']=(train.tp04+train.tp09)/2
train['Openness to Experiences']=(train.tp05+train.tp10)/2

# %%
total_negative_cols = ["QeA", "QfA", "QkA", "QqA", "QrA", "QaA", "QdA", "QgA", "QiA", "QnA"]
test[total_negative_cols] = 6-test[total_negative_cols]
test['mach_score'] = test.apply(lambda x:x.iloc[0:40:2].mean(),axis=1)

# %%
test[['tp02','tp04','tp06','tp08','tp10']]= 6-test[['tp02','tp04','tp06','tp08','tp10']]

test['Extraversion']=(test.tp01+test.tp06)/2
test['Agreeableness']=(test.tp02+test.tp07)/2
test['Conscientiousness']=(test.tp03+test.tp08)/2
test['Emotional Stability']=(test.tp04+test.tp09)/2
test['Openness to Experiences']=(test.tp05+test.tp10)/2

# %%
test
# Out:
#        QaA  QaE  QbA   QbE  QcA   QcE  QdA   QdE  QeA   QeE  ...  wr_10  \
# 0      3.0  736  2.0  2941  3.0  4621  5.0  4857  4.0  2550  ...      1
# 1      3.0  514  2.0  1952  3.0  1552  3.0   821  2.0  1150  ...      0
# 2      3.0  500  2.0  2507  4.0   480  4.0   614  4.0  1326  ...      1
# 3      5.0  669  1.0  1050  5.0  1435  4.0  2252  1.0  2533  ...      1
# 4      4.0  499  1.0  1243  5.0   845  4.0  1666  4.0   925  ...      1
# ...    ...  ...  ...   ...  ...   ...  ...   ...  ...   ...  ...    ...
# 11378  1.0  427  5.0  1066  5.0   588  5.0   560  4.0  1110  ...      1
# 11379  5.0  314  5.0   554  5.0   230  5.0   956  4.0  1173  ...      1
# 11380  5.0  627  2.0   799  1.0   739  4.0  1123  5.0   829  ...      1
# 11381  4.0  539  1.0  2090  2.0  4642  5.0   673  4.0  1185  ...      1
# 11382  4.0  541  4.0   900  5.0   691  4.0  1951  5.0  2317  ...      0
#
#        wr_11  wr_12  wr_13  mach_score  Extraversion  Agreeableness  \
# 0          0      1      1        2.45           3.0            3.5
# 1          0      0      0        2.80           3.0            3.0
# 2          0      1      1        3.55           5.5            3.0
# 3          1      1      1        3.35           0.0            0.5
# 4          1      1      1        2.90           6.0            5.0
# ...      ...    ...    ...         ...           ...            ...
# 11378      0      1      1        3.20           1.5            3.5
# 11379      1      1      1        4.55           1.0            3.0
# 11380      0      1      1        3.15           4.0            2.5
# 11381      1      1      0        3.05           4.0            0.5
# 11382      1      0      0        3.40           3.5            2.0
#
#        Conscientiousness  Emotional Stability  Openness to Experiences
# 0                    2.0                  3.0                      1.5
# 1                    3.0                  3.0                      3.0
# 2                    3.5                  5.0                      5.5
# 3                    1.0                  0.5                      0.0
# 4                    3.0                  4.0                      3.0
# ...                  ...                  ...                      ...
# 11378                3.0                  3.5                      0.5
# 11379                4.0                  6.0                      1.0
# 11380                0.5                  0.0                      1.0
# 11381                0.5                  0.5                      0.5
# 11382                1.5                  5.5                      0.0
#
# [11383 rows x 82 columns]

# %%
train=train.drop(['QaA', 'QaE', 'QbA', 'QbE', 'QcA', 'QcE', 'QdA', 'QdE', 'QeA', 'QeE',
       'QfA', 'QfE', 'QgA', 'QgE', 'QhA', 'QhE', 'QiA', 'QiE', 'QjA', 'QjE',
       'QkA', 'QkE', 'QlA', 'QlE', 'QmA', 'QmE', 'QnA', 'QnE', 'QoA', 'QoE',
       'QpA', 'QpE', 'QqA', 'QqE', 'QrA', 'QrE', 'QsA', 'QsE', 'QtA', 'QtE',
                 'tp01', 'tp02', 'tp03', 'tp04', 'tp05',
       'tp06', 'tp07', 'tp08', 'tp09', 'tp10', 'wf_01', 'wf_02',
       'wf_03', 'wr_01', 'wr_02', 'wr_03', 'wr_04', 'wr_05', 'wr_06', 'wr_07',
       'wr_08', 'wr_09', 'wr_10', 'wr_11', 'wr_12', 'wr_13'], axis=1)

# %%
train
# Out:
#       age_group  education  engnat  familysize  gender  hand  married   race  \
# 0           30s          2       1           4  Female     1        3  White
# 1           20s          4       2           3  Female     1        1  Asian
# 2           30s          3       1           3    Male     1        2  White
# 3           20s          4       2           0  Female     1        1  Asian
# 4           20s          3       1           2    Male     1        2  White
# ...         ...        ...     ...         ...     ...   ...      ...    ...
# 45524       10s          2       1           1  Female     3        1  White
# 45525       30s          2       1           2    Male     1        1  White
# 45526       10s          2       1           1  Female     1        1  White
# 45527       40s          4       1           2    Male     3        1  White
# 45528       20s          2       1           3    Male     1        1  White
#
#               religion  urban  voted  mach_score  Extraversion  Agreeableness  \
# 0                Other      1      2        2.95           3.5            5.5
# 1                Hindu      3      2        2.60           2.5            4.0
# 2                Other      2      1        1.90           2.0            2.5
# 3                Hindu      3      1        3.35           2.5            1.5
# 4             Agnostic      1      1        3.00           2.5            2.5
# ...                ...    ...    ...         ...           ...            ...
# 45524           Jewish      3      2        4.15           0.5            3.5
# 45525          Atheist      1      2        3.80           2.5            3.5
# 45526  Christian_Other      2      1        1.50           4.5            1.0
# 45527          Atheist      2      1        2.90           3.0            3.5
# 45528         Agnostic      2      1        3.40           4.5            3.0
#
#        Conscientiousness  Emotional Stability  Openness to Experiences
# 0                    2.0                  4.5                      2.5
# 1                    1.0                  3.0                      1.5
# 2                    0.5                  1.0                      3.0
# 3                    2.0                  3.0                      2.0
# 4                    0.5                  1.0                      0.0
# ...                  ...                  ...                      ...
# 45524                6.0                  5.5                      2.0
# 45525                2.0                  2.0                      1.0
# 45526                3.0                  1.5                      0.0
# 45527                2.0                  2.0                      1.0
# 45528                2.0                  2.5                      3.5
#
# [45529 rows x 17 columns]

# %%
test=test.drop(['QaA', 'QaE', 'QbA', 'QbE', 'QcA', 'QcE', 'QdA', 'QdE', 'QeA', 'QeE',
       'QfA', 'QfE', 'QgA', 'QgE', 'QhA', 'QhE', 'QiA', 'QiE', 'QjA', 'QjE',
       'QkA', 'QkE', 'QlA', 'QlE', 'QmA', 'QmE', 'QnA', 'QnE', 'QoA', 'QoE',
       'QpA', 'QpE', 'QqA', 'QqE', 'QrA', 'QrE', 'QsA', 'QsE', 'QtA', 'QtE',
                 'tp01', 'tp02', 'tp03', 'tp04', 'tp05',
       'tp06', 'tp07', 'tp08', 'tp09', 'tp10', 'wf_01', 'wf_02',
       'wf_03', 'wr_01', 'wr_02', 'wr_03', 'wr_04', 'wr_05', 'wr_06', 'wr_07',
       'wr_08', 'wr_09', 'wr_10', 'wr_11', 'wr_12', 'wr_13'], axis=1)
test
# Out:
#       age_group  education  engnat  familysize  gender  hand  married   race  \
# 0           10s          2       2           3    Male     1        1  White
# 1           10s          2       2           2    Male     2        1  Other
# 2           30s          3       2           7    Male     1        2  Other
# 3           60s          4       1           4    Male     1        2  White
# 4           10s          2       1           3    Male     1        1  White
# ...         ...        ...     ...         ...     ...   ...      ...    ...
# 11378       20s          3       2           3  Female     1        1  Other
# 11379       10s          2       2           1  Female     1        1  Asian
# 11380       30s          4       1           4    Male     1        2  White
# 11381       40s          2       1           3  Female     1        2  White
# 11382       20s          4       2           2  Female     1        1  Asian
#
#                    religion  urban  mach_score  Extraversion  Agreeableness  \
# 0      Christian_Protestant      2        2.45           3.0            3.5
# 1        Christian_Catholic      3        2.80           3.0            3.0
# 2           Christian_Other      1        3.55           5.5            3.0
# 3        Christian_Catholic      2        3.35           0.0            0.5
# 4                  Agnostic      2        2.90           6.0            5.0
# ...                     ...    ...         ...           ...            ...
# 11378    Christian_Catholic      3        3.20           1.5            3.5
# 11379              Agnostic      2        4.55           1.0            3.0
# 11380               Atheist      1        3.15           4.0            2.5
# 11381               Atheist      2        3.05           4.0            0.5
# 11382       Christian_Other      3        3.40           3.5            2.0
#
#        Conscientiousness  Emotional Stability  Openness to Experiences
# 0                    2.0                  3.0                      1.5
# 1                    3.0                  3.0                      3.0
# 2                    3.5                  5.0                      5.5
# 3                    1.0                  0.5                      0.0
# 4                    3.0                  4.0                      3.0
# ...                  ...                  ...                      ...
# 11378                3.0                  3.5                      0.5
# 11379                4.0                  6.0                      1.0
# 11380                0.5                  0.0                      1.0
# 11381                0.5                  0.5                      0.5
# 11382                1.5                  5.5                      0.0
#
# [11383 rows x 16 columns]

# %%
print(train.shape)
print(test.shape)
print(submission.shape)
# Out:
# (45529, 17)
# (11383, 16)
# (11383, 2)

# %%
from pycaret.classification import *

# %%
clf = setup(data = train, target = 'voted')
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_5d94859a_12ce_11eb_b912_a0510bbec886" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row0_col1" class="data row0 col1" >5891</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row2_col1" class="data row2 col1" >1: 0, 2: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row3_col1" class="data row3 col1" >(45529, 17)</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row5_col1" class="data row5 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row6_col1" class="data row6 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row10_col1" class="data row10 col1" >(31870, 17)</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row11_col1" class="data row11 col1" >(22308, 50)</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row12_col1" class="data row12 col1" >(9562, 50)</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5d94859a_12ce_11eb_b912_a0510bbec886level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_5d94859a_12ce_11eb_b912_a0510bbec886row18_col1" class="data row18 col1" >None</td>
#             </tr

# %%
best_3 = compare_models(sort = 'AUC', n_select = 3)
# Out:
# <style  type="text/css" >
#     #T_974dc80a_12cf_11eb_a5fa_a0510bbec886 th {
#           text-align: left;
#     }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row0_col0 {
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row0_col7 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row0_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row1_col0 {
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row1_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row1_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row1_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row1_col7 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row1_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row2_col0 {
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row2_col7 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row2_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row3_col0 {
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row3_col7 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row3_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row4_col0 {
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row4_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row4_col7 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row4_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row5_col0 {
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row5_col7 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row5_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row6_col0 {
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row6_col7 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row6_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row7_col0 {
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec886row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_974dc80a_12cf_11eb_a5fa_a0510bbec8

# %%
blended = blend_models(estimator_list = best_3, fold = 5, method = 'soft')
# Out:
# <style  type="text/css" >
#     #T_e40a6af6_12cf_11eb_ad95_a0510bbec886row5_col0 {
#             background:  yellow;
#         }    #T_e40a6af6_12cf_11eb_ad95_a0510bbec886row5_col1 {
#             background:  yellow;
#         }    #T_e40a6af6_12cf_11eb_ad95_a0510bbec886row5_col2 {
#             background:  yellow;
#         }    #T_e40a6af6_12cf_11eb_ad95_a0510bbec886row5_col3 {
#             background:  yellow;
#         }    #T_e40a6af6_12cf_11eb_ad95_a0510bbec886row5_col4 {
#             background:  yellow;
#         }    #T_e40a6af6_12cf_11eb_ad95_a0510bbec886row5_col5 {
#             background:  yellow;
#         }    #T_e40a6af6_12cf_11eb_ad95_a0510bbec886row5_col6 {
#             background:  yellow;
#         }</style><table id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row0_col0" class="data row0 col0" >0.6916</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row0_col1" class="data row0 col1" >0.7667</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row0_col2" class="data row0 col2" >0.6529</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row0_col3" class="data row0 col3" >0.7507</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row0_col4" class="data row0 col4" >0.6984</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row0_col5" class="data row0 col5" >0.386</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row0_col6" class="data row0 col6" >0.39</td>
#             </tr>
#             <tr>
#                         <th id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row1_col0" class="data row1 col0" >0.6887</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row1_col1" class="data row1 col1" >0.762</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row1_col2" class="data row1 col2" >0.6344</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row1_col3" class="data row1 col3" >0.757</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row1_col4" class="data row1 col4" >0.6903</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row1_col5" class="data row1 col5" >0.3822</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row1_col6" class="data row1 col6" >0.3883</td>
#             </tr>
#             <tr>
#                         <th id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row2_col0" class="data row2 col0" >0.6941</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row2_col1" class="data row2 col1" >0.7651</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row2_col2" class="data row2 col2" >0.6459</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row2_col3" class="data row2 col3" >0.7588</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row2_col4" class="data row2 col4" >0.6978</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row2_col5" class="data row2 col5" >0.3921</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row2_col6" class="data row2 col6" >0.3973</td>
#             </tr>
#             <tr>
#                         <th id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row3_col0" class="data row3 col0" >0.6974</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row3_col1" class="data row3 col1" >0.7668</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row3_col2" class="data row3 col2" >0.6426</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row3_col3" class="data row3 col3" >0.7664</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row3_col4" class="data row3 col4" >0.6991</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row3_col5" class="data row3 col5" >0.3994</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row3_col6" class="data row3 col6" >0.4057</td>
#             </tr>
#             <tr>
#                         <th id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row4_col0" class="data row4 col0" >0.6947</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row4_col1" class="data row4 col1" >0.7705</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row4_col2" class="data row4 col2" >0.6482</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row4_col3" class="data row4 col3" >0.7583</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row4_col4" class="data row4 col4" >0.6989</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row4_col5" class="data row4 col5" >0.3931</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row4_col6" class="data row4 col6" >0.3981</td>
#             </tr>
#             <tr>
#                         <th id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886level0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row5_col0" class="data row5 col0" >0.6933</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row5_col1" class="data row5 col1" >0.7662</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row5_col2" class="data row5 col2" >0.6448</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row5_col3" class="data row5 col3" >0.7582</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row5_col4" class="data row5 col4" >0.6969</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row5_col5" class="data row5 col5" >0.3906</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row5_col6" class="data row5 col6" >0.3959</td>
#             </tr>
#             <tr>
#                         <th id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886level0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row6_col0" class="data row6 col0" >0.0029</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row6_col1" class="data row6 col1" >0.0028</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row6_col2" class="data row6 col2" >0.0062</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row6_col3" class="data row6 col3" >0.005</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row6_col4" class="data row6 col4" >0.0033</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec886row6_col5" class="data row6 col5" >0.0059</td>
#                         <td id="T_e40a6af6_12cf_11eb_ad95_a0510bbec8

# %%
pred_holdout = predict_model(blended)
# Out:
#                Model  Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0  Voting Classifier    0.6953  0.7645  0.6489  0.7589  0.6996  0.3942  0.3992

# %%
final_model = finalize_model(blended)

# %%
predictions = predict_model(final_model, data = test)

# %%
predictions
# Out:
#       age_group  education  engnat  familysize  gender  hand  married   race  \
# 0           10s          2       2           3    Male     1        1  White
# 1           10s          2       2           2    Male     2        1  Other
# 2           30s          3       2           7    Male     1        2  Other
# 3           60s          4       1           4    Male     1        2  White
# 4           10s          2       1           3    Male     1        1  White
# ...         ...        ...     ...         ...     ...   ...      ...    ...
# 11378       20s          3       2           3  Female     1        1  Other
# 11379       10s          2       2           1  Female     1        1  Asian
# 11380       30s          4       1           4    Male     1        2  White
# 11381       40s          2       1           3  Female     1        2  White
# 11382       20s          4       2           2  Female     1        1  Asian
#
#                    religion  urban  mach_score  Extraversion  Agreeableness  \
# 0      Christian_Protestant      2        2.45           3.0            3.5
# 1        Christian_Catholic      3        2.80           3.0            3.0
# 2           Christian_Other      1        3.55           5.5            3.0
# 3        Christian_Catholic      2        3.35           0.0            0.5
# 4                  Agnostic      2        2.90           6.0            5.0
# ...                     ...    ...         ...           ...            ...
# 11378    Christian_Catholic      3        3.20           1.5            3.5
# 11379              Agnostic      2        4.55           1.0            3.0
# 11380               Atheist      1        3.15           4.0            2.5
# 11381               Atheist      2        3.05           4.0            0.5
# 11382       Christian_Other      3        3.40           3.5            2.0
#
#        Conscientiousness  Emotional Stability  Openness to Experiences Label  \
# 0                    2.0                  3.0                      1.5     2
# 1                    3.0                  3.0                      3.0     2
# 2                    3.5                  5.0                      5.5     2
# 3                    1.0                  0.5                      0.0     1
# 4                    3.0                  4.0                      3.0     2
# ...                  ...                  ...                      ...   ...
# 11378                3.0                  3.5                      0.5     1
# 11379                4.0                  6.0                      1.0     2
# 11380                0.5                  0.0                      1.0     1
# 11381                0.5                  0.5                      0.5     1
# 11382                1.5                  5.5                      0.0     2
#
#         Score
# 0      0.6288
# 1      0.8573
# 2      0.5189
# 3      0.1737
# 4      0.7836
# ...       ...
# 11378  0.4614
# 11379  0.9087
# 11380  0.2768
# 11381  0.3409
# 11382  0.6026
#
# [11383 rows x 18 columns]

# %%
submission['voted'] = predictions['Score']

# %%
submission.to_csv('submission_proba.csv', index = False)
